# %%
import spacy
import pandas as pd
import numpy as np

nlp = spacy.load('en_core_web_md')

amazon = pd.read_csv('Datafiniti_Amazon_Consumer_reviews_of_Amazon_Products.csv')
amazon.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
# Setting out the different datatypes for the different columns

#data = pd.read_csv('sample_reviews.csv', dtype={
#    "id":'str',
 #   "dateAdded":'str',
  #  "dateUpdated": 'str',
   # "name": 'str',
    #"asins": 'str',
#    "brand": 'str',
 #   "primaryCategories": 'str',
  #  "imageURLs": 'str',
   # "keys": 'str',
#    "reviews.dateSeen": 'str',      # set later to date if possible, 3 rows
 #   "reviews.doRecommend": 'str',   # bool?
  #  "reviews.id": 'str',
   # "reviews.numHelpful": 'str',
#    "reviews.rating": 'int',
 #   "reviews.sourceURLs": 'str',
  #  "reviews.text": 'str',
   # "reviews.title": 'str',
  #  "reviews.username": 'str'
#})

low_memory=False

# %%
cleaned = amazon[['reviews.text', 'reviews.title', 'reviews.username']]
cleaned
# Out:
#                                            reviews.text  \
# 0     I thought it would be as big as small paper bu...
# 1     This kindle is light and easy to use especiall...
# 2     Didnt know how much i'd use a kindle so went f...
# 3     I am 100 happy with my purchase. I caught it o...
# 4     Solid entry level Kindle. Great for kids. Gift...
# ...                                                 ...
# 4995  This is a great tablet for the price. Amazon i...
# 4996  This tablet is the perfect size and so easy to...
# 4997  Purchased this for my son. Has room to upgrade...
# 4998  I had some thoughts about getting this for a 5...
# 4999  this is a steal, have 8 gb model as well.This ...
#
#                                      reviews.title reviews.username
# 0                                        Too small           llyyue
# 1     Great light reader. Easy to use at the beach           Charmi
# 2                              Great for the price     johnnyjojojo
# ...

# %%
cleaned.dropna(inplace=True, axis=0)
cleaned.isnull().sum()
# Out:
# C:\Users\alecs\AppData\Local\Temp\ipykernel_18876\805810464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned.dropna(inplace=True, axis=0)
# reviews.text        0
# reviews.title       0
# reviews.username    0
# dtype: int64

# %%
text = cleaned['reviews.text']
text
# Out:
# 0       I thought it would be as big as small paper bu...
# 1       This kindle is light and easy to use especiall...
# 2       Didnt know how much i'd use a kindle so went f...
# 3       I am 100 happy with my purchase. I caught it o...
# 4       Solid entry level Kindle. Great for kids. Gift...
#                               ...
# 4995    This is a great tablet for the price. Amazon i...
# 4996    This tablet is the perfect size and so easy to...
# 4997    Purchased this for my son. Has room to upgrade...
# 4998    I had some thoughts about getting this for a 5...
# 4999    this is a steal, have 8 gb model as well.This ...
# Name: reviews.text, Length: 4986, dtype: object

# %%
def preprocess(text):
    if not isinstance(text, str): 
        return text
    doc =nlp(text.lower().strip())
    processed = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return ' '.join(processed)

cleaned['processed.text'] = cleaned['reviews.text'].apply(preprocess)
# Out:
# C:\Users\alecs\AppData\Local\Temp\ipykernel_18876\1300927533.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned['processed.text'] = cleaned['reviews.text'].apply(preprocess)

# %%
cleaned.head()
# Out:
#                                         reviews.text  \
# 0  I thought it would be as big as small paper bu...
# 1  This kindle is light and easy to use especiall...
# 2  Didnt know how much i'd use a kindle so went f...
# 3  I am 100 happy with my purchase. I caught it o...
# 4  Solid entry level Kindle. Great for kids. Gift...
#
#                                   reviews.title reviews.username  \
# 0                                     Too small           llyyue
# 1  Great light reader. Easy to use at the beach           Charmi
# 2                           Great for the price     johnnyjojojo
# 3                                   A Great Buy          Kdperry
# 4      Solid entry-level Kindle. Great for kids      Johnnyblack
#
#                                       processed.text
# 0  think big small paper turn like palm think sma...
# 1             kindle light easy use especially beach
# 2  not know use kindle go low end m happy little ...
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import defaultdict
from textblob import TextBlob

nlp = spacy.load("en_core_web_md")
positive_words = defaultdict(int)
negative_words = defaultdict(int)

# %%
for sentence in cleaned['processed.text']:
    doc = nlp(sentence)
    tokens = [token.lemma_.lower().strip() for token in doc if not token.is_stop and token.is_alpha]
    for token in tokens:
        blob = TextBlob(str(token))
        polarity = blob.sentiment.polarity

        if polarity > 0:
            positive_words[token.lower()] += 1
        elif polarity < 0:
            negative_words[token.lower()] += 1

# %%
def sentiment_analysis(cleaned):
    for key, value in cleaned.items():
        doc = nlp(value)
        print(f'\nReview: {key, value}')
        print(f'Sentiment: {doc._.blob.polarity}')

# %%
# Compare reviews
my_reviews = amazon['reviews.text'].iloc[[5, 10, 25, 52, 99]]
sentiment_analysis(my_reviews)
# Out:
# Review: (5, "This make an excellent ebook reader. Don't expect much from this device except to read basic ebooks. The good thing is it's cheap and good to read in the sun.")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 3
#       1 # Compare reviews
#       2 my_reviews = amazon['reviews.text'].iloc[[5, 10, 25, 52, 99]]
# ----> 3 sentiment_analysis(my_reviews)
#
# Cell In[63], line 5, in sentiment_analysis(cleaned)
#       3 doc = nlp(value)
#       4 print(f'\nReview: {key, value}')
# ----> 5 print(f'Sentiment: {doc._.blob.polarity}')
#
# File c:\Users\alecs\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\tokens\underscore.py:48, in Underscore.__getattr__(self, name)
#      46 def __getattr__(self, name: str) -> Any:
#      47     if name not in self._extensions:
# ---> 48         raise AttributeError(Errors.E046.format(name=name))
# ...
